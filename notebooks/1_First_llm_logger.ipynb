# %%
import deepeval
import os
from deepeval import test_case
from deepeval import evaluate
from dotenv import load_dotenv
from openai import api_key
from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric
import os
load_dotenv()

DEEP_EVAL_API_KEY = os.getenv("DEEV_EVAL_KEY")
deepeval.login(DEEP_EVAL_API_KEY)
import sys
# 1. Get the path to the folder ABOVE 'notebooks'
# This points to: d:\pyhton_projects\Test_AI_LLM_Apps
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# 2. Add that root folder to the path
if project_root not in sys.path:
    sys.path.insert(0, project_root) # insert at 0 to prioritize this path
from modules.local_model_llama_with_logger import trace_judge



# os.environ["OPENAI_API_KEY"] = "your_api_key_here"

answerRelevancyMetric=AnswerRelevancyMetric(model=trace_judge,threshold=0.7,verbose_mode=True)

test_case = LLMTestCase(
    input="What is capital of India?",
    actual_output="New Delhi",
    expected_output="New Delhi is the Capital of India."
)

evaluate(test_cases=[test_case],metrics=[answerRelevancyMetric])
# Out:
# 🎉🥳 Congratulations! You've successfully logged in! 🙌
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 28
#      24
#      25
#      26 # os.environ["OPENAI_API_KEY"] = "your_api_key_here"
#      27
# ---> 28 answerRelevancyMetric=AnswerRelevancyMetric(model=trace_judge,threshold=0.7,verbose_mode=True)
#      29
#      30 test_case = LLMTestCase(
#      31     input="What is capital of India?",
#
# File d:\pyhton_projects\Test_AI_LLM_Apps\.venv\Lib\site-packages\deepeval\metrics\answer_relevancy\answer_relevancy.py:47, in AnswerRelevancyMetric.__init__(self, threshold, model, include_reason, async_mode, strict_mode, verbose_mode, evaluation_template)
#      34 def __init__(
#      35     self,
#      36     threshold: float = 0.5,
#    (...)     44     ] = AnswerRelevancyTemplate,
#      45 ):
#      46     self.threshold = 1 if strict_mode else threshold
# ---> 47     self.model, self.using_native_model = initialize_model(model)
#      48     self.evaluation_model = self.model.get_model_name()
#      49     self.include_reason = include_reason
#
# File d:\pyhton_projects\Test_AI_LLM_Apps\.venv\Lib\site-packages\deepeval\metrics\utils.py:614, in initialize_model(model)
#     611     return GPTModel(model=model), True
#     613 # Otherwise (the model is a wrong type), we raise an error
# --> 614 raise TypeError(
#     615     f"Unsupported type for model: {type(model)}. Expected None, str, DeepEvalBaseLLM, GPTModel, AzureOpenAIModel, LiteLLMModel, OllamaModel, LocalModel."
#     616 )
#
# TypeError: Unsupported type for model: <class 'function'>. Expected None, str, DeepEvalBaseLLM, GPTModel, AzureOpenAIModel, LiteLLMModel, OllamaModel, LocalModel.
